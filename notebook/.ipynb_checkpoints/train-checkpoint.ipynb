# %%
from preprocessing import remove_outliers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from preprocessing import remove_outliers
#
# ModuleNotFoundError: No module named 'preprocessing'
